# %%
import pandas as pd
import seaborn as sns
data=pd.read_excel("Karachi_car_data.xlsx")
data
# Out:
#          Ad Id                                                URL     City  \
# 0      7487394  http://www.pakwheels.com/used-cars/adam-revo-2...  Karachi
# 1      7482981  http://www.pakwheels.com/used-cars/adam-revo-2...  Karachi
# 2      7477481  http://www.pakwheels.com/used-cars/adam-revo-2...  Karachi
# 3      7471489  http://www.pakwheels.com/used-cars/audi-q2-201...  Karachi
# 4      7482518  http://www.pakwheels.com/used-cars/audi-a3-201...  Karachi
# ...        ...                                                ...      ...
# 15303  7419122  http://www.pakwheels.com/used-cars/volkswagen-...  Karachi
# 15304  7220824  http://www.pakwheels.com/used-cars/volvo-other...  Karachi
# 15305  7465551  http://www.pakwheels.com/used-cars/willys-m38-...  Karachi
# 15306  6451593  http://www.pakwheels.com/used-cars/willys-m38-...  Karachi
# 15307  7339978  http://www.pakwheels.com/used-cars/willys-m38-...  Karachi
#
# ...

# %%
data.drop(['Ad Id','URL','City','itemCondition','color','priceCurrency', 'car_specs','Brand','Name'],axis=1, inplace=True)
data
# Out:
#        Model  modelDate manufacturer fuelType vehicleTransmission  \
# 0       Revo       2021         Adam   Diesel           Automatic
# 1       Revo       2022         Adam   Diesel           Automatic
# 2       Revo       2020         Adam   Diesel           Automatic
# 3         Q2       2018         Audi   Petrol           Automatic
# 4         A3       2018         Audi   Petrol           Automatic
# ...      ...        ...          ...      ...                 ...
# 15303   Polo       1972   Volkswagen   Petrol              Manual
# 15304  Other       1984        Volvo   Petrol              Manual
# 15305    M38       1952       Willys   Diesel              Manual
# 15306    M38       1964       Willys   Diesel              Manual
# 15307    M38       1960       Willys   Diesel              Manual
#
#        Engine_Displacement(cc)  mileageFromOdometer (km)  Offering_Price
# 0                       2800.0                     46900        12600000
# ...

# %%
data.isna().sum()
# Out:
# Model                        0
# modelDate                    0
# manufacturer                 0
# fuelType                     0
# vehicleTransmission          0
# Engine_Displacement(cc)     27
# mileageFromOdometer (km)     0
# Offering_Price               0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.columns
# Out:
# Index(['Model', 'modelDate', 'manufacturer', 'fuelType', 'vehicleTransmission',
#        'Engine_Displacement(cc)', 'mileageFromOdometer (km)',
#        'Offering_Price'],
#       dtype='object')

# %%
column_mapping = {
    'fuelType': 'fuel_type',
    'vehicleTransmission':'transmission',
    'mileageFromOdometer (km)': 'kms_driven',
    'Offering_Price': 'price_pkr',
    'Engine_Displacement(cc)': 'engine_cc',
    'modelDate': 'model_year',
    'vehicle_transmission': 'transmission',
    'Model': 'car_name',
    
}

data.rename(columns=column_mapping, inplace=True)

data
# Out:
#       car_name  model_year manufacturer fuel_type transmission  engine_cc  \
# 0         Revo        2021         Adam    Diesel    Automatic     2800.0
# 1         Revo        2022         Adam    Diesel    Automatic     2800.0
# 2         Revo        2020         Adam    Diesel    Automatic     2800.0
# 3           Q2        2018         Audi    Petrol    Automatic     1000.0
# 4           A3        2018         Audi    Petrol    Automatic     1200.0
# ...        ...         ...          ...       ...          ...        ...
# 15303     Polo        1972   Volkswagen    Petrol       Manual     1000.0
# 15304    Other        1984        Volvo    Petrol       Manual     2400.0
# 15305      M38        1952       Willys    Diesel       Manual     2200.0
# 15306      M38        1964       Willys    Diesel       Manual     2400.0
# 15307      M38        1960       Willys    Diesel       Manual     2400.0
#
#        kms_driven  price_pkr
# 0           46900   12600000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15281 entries, 0 to 15307
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car_name      15281 non-null  object
#  1   model_year    15281 non-null  int64
#  2   manufacturer  15281 non-null  object
#  3   fuel_type     15281 non-null  object
#  4   transmission  15281 non-null  object
#  5   engine_cc     15281 non-null  float64
#  6   kms_driven    15281 non-null  int64
#  7   price_pkr     15281 non-null  int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 1.0+ MB

# %% [markdown]
# # dropping duplicates

# %%
data= data[~data.duplicated(subset=['car_name','price_pkr', 'model_year', 'kms_driven', 'transmission', 'fuel_type','engine_cc','manufacturer' ])]
data
# Out:
#       car_name  model_year manufacturer fuel_type transmission  engine_cc  \
# 0         Revo        2021         Adam    Diesel    Automatic     2800.0
# 1         Revo        2022         Adam    Diesel    Automatic     2800.0
# 2         Revo        2020         Adam    Diesel    Automatic     2800.0
# 3           Q2        2018         Audi    Petrol    Automatic     1000.0
# 4           A3        2018         Audi    Petrol    Automatic     1200.0
# ...        ...         ...          ...       ...          ...        ...
# 15303     Polo        1972   Volkswagen    Petrol       Manual     1000.0
# 15304    Other        1984        Volvo    Petrol       Manual     2400.0
# 15305      M38        1952       Willys    Diesel       Manual     2200.0
# 15306      M38        1964       Willys    Diesel       Manual     2400.0
# 15307      M38        1960       Willys    Diesel       Manual     2400.0
#
#        kms_driven  price_pkr
# 0           46900   12600000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13644 entries, 0 to 15307
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car_name      13644 non-null  object
#  1   model_year    13644 non-null  int64
#  2   manufacturer  13644 non-null  object
#  3   fuel_type     13644 non-null  object
#  4   transmission  13644 non-null  object
#  5   engine_cc     13644 non-null  float64
#  6   kms_driven    13644 non-null  int64
#  7   price_pkr     13644 non-null  int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 959.3+ KB

# %%
# columns_to_convert = ['engine_cc', 'kms_driven']

# data[columns_to_convert] = data[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# data[columns_to_convert] = data[columns_to_convert].astype(float)

data[['kms_driven','price_pkr','model_year']]=data[['kms_driven','price_pkr','model_year']].astype(float)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14544\3293963514.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['kms_driven','price_pkr','model_year']]=data[['kms_driven','price_pkr','model_year']].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13644 entries, 0 to 15307
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car_name      13644 non-null  object
#  1   model_year    13644 non-null  float64
#  2   manufacturer  13644 non-null  object
#  3   fuel_type     13644 non-null  object
#  4   transmission  13644 non-null  object
#  5   engine_cc     13644 non-null  float64
#  6   kms_driven    13644 non-null  float64
#  7   price_pkr     13644 non-null  float64
# dtypes: float64(4), object(4)
# memory usage: 959.3+ KB

# %%
data['manufacturer'].unique()
# Out:
# array(['Adam', 'Audi', 'BAIC', 'BMW', 'Changan', 'Chery', 'Chevrolet',
#        'Daehan', 'Daihatsu', 'Datsun', 'DFSK', 'FAW', 'Ford', 'GMC',
#        'Haval', 'Honda', 'Hyundai', 'Isuzu', 'Jaguar', 'Jeep',
#        'JW Forland', 'KIA', 'Land Rover', 'Lexus', 'Mazda',
#        'Mercedes Benz', 'MG', 'Mitsubishi', 'Mushtaq', 'Nissan', 'Opel',
#        'Peugeot', 'Porsche', 'Prince', 'Proton', 'Range Rover', 'Roma',
#        'Sogo', 'Sokon', 'SsangYong', 'Subaru', 'Suzuki', 'Toyota',
#        'United', 'Volkswagen', 'Volvo', 'Willys'], dtype=object)

# %% [markdown]
# # Two Words brands Exceptions >>>>: 'Mercedes Benz', 'Range Rover','Land Rover','Alfa Romeo','JW Forland','Classic Cars'

# %%
exceptions=['Mercedes Benz', 'Range Rover','Land Rover','JW Forland']
corrected= ['Mercedes-Benz', 'Range-Rover','Land-Rover','JW-Forland']
for i in range(len(exceptions)):
    data= data.replace(exceptions[i], corrected[i])

# %%
data['manufacturer'].unique()
# Out:
# array(['Adam', 'Audi', 'BAIC', 'BMW', 'Changan', 'Chery', 'Chevrolet',
#        'Daehan', 'Daihatsu', 'Datsun', 'DFSK', 'FAW', 'Ford', 'GMC',
#        'Haval', 'Honda', 'Hyundai', 'Isuzu', 'Jaguar', 'Jeep',
#        'JW-Forland', 'KIA', 'Land-Rover', 'Lexus', 'Mazda',
#        'Mercedes-Benz', 'MG', 'Mitsubishi', 'Mushtaq', 'Nissan', 'Opel',
#        'Peugeot', 'Porsche', 'Prince', 'Proton', 'Range-Rover', 'Roma',
#        'Sogo', 'Sokon', 'SsangYong', 'Subaru', 'Suzuki', 'Toyota',
#        'United', 'Volkswagen', 'Volvo', 'Willys'], dtype=object)

# %%
data
# Out:
#       car_name  model_year manufacturer fuel_type transmission  engine_cc  \
# 0         Revo      2021.0         Adam    Diesel    Automatic     2800.0
# 1         Revo      2022.0         Adam    Diesel    Automatic     2800.0
# 2         Revo      2020.0         Adam    Diesel    Automatic     2800.0
# 3           Q2      2018.0         Audi    Petrol    Automatic     1000.0
# 4           A3      2018.0         Audi    Petrol    Automatic     1200.0
# ...        ...         ...          ...       ...          ...        ...
# 15303     Polo      1972.0   Volkswagen    Petrol       Manual     1000.0
# 15304    Other      1984.0        Volvo    Petrol       Manual     2400.0
# 15305      M38      1952.0       Willys    Diesel       Manual     2200.0
# 15306      M38      1964.0       Willys    Diesel       Manual     2400.0
# 15307      M38      1960.0       Willys    Diesel       Manual     2400.0
#
#        kms_driven   price_pkr
# 0         46900.0  12600000.0
# ...

# %% [markdown]
# # Outliers

# %%
sns.boxplot(data['price_pkr'])
# Out:
# <AxesSubplot:>

# %%
data.sort_values(by='price_pkr', ascending=False)
# Out:
#            car_name  model_year manufacturer fuel_type transmission  \
# 4526      LX Series      2022.0        Lexus    Petrol    Automatic
# 4548      LX Series      2021.0        Lexus    Petrol    Automatic
# 9929   Land Cruiser      2023.0       Toyota    Petrol    Automatic
# 9805   Land Cruiser      2023.0       Toyota    Petrol    Automatic
# 13441  Land Cruiser      2022.0       Toyota    Petrol    Automatic
# ...             ...         ...          ...       ...          ...
# 8702             FX      1988.0       Suzuki    Petrol       Manual
# 7908             FX      1985.0       Suzuki    Petrol       Manual
# 617         Charade      1983.0     Daihatsu    Petrol       Manual
# 6872             FX      1988.0       Suzuki    Petrol       Manual
# 7226             FX      1988.0       Suzuki    Petrol       Manual
#
#        engine_cc  kms_driven    price_pkr
# 4526      3400.0        25.0  190000000.0
# 4548      5663.0        40.0  130000000.0
# ...

# %%
data = data[~((data['manufacturer'] == 'Lexus') & (data['price_pkr'] >= 125100000.0))]
sns.boxplot(data['price_pkr'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Correlation Check

# %%
def correlation (dataset, threshold):
    col_corr=set()
    corr_matrix=data.corr()
    
    for i in range (len(corr_matrix.columns)):
        for j in range (i):
            if abs(corr_matrix.iloc[i,j]) > threshold:
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr
corr_features=correlation(data, 0.7)
corr_features
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14544\2886442014.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix=data.corr()
# set()

# %%
data.isna().sum()
# Out:
# car_name        0
# model_year      0
# manufacturer    0
# fuel_type       0
# transmission    0
# engine_cc       0
# kms_driven      0
# price_pkr       0
# dtype: int64

# %%
data.dropna(inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14544\286435216.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)

# %%
car_name_counts = data['car_name'].value_counts()
data = data[~(data['car_name'].isin(car_name_counts[car_name_counts <= 5].index))]

# %%
data = data[~(data['car_name']=='Other')]

# %%
data
# Out:
#        car_name  model_year manufacturer fuel_type transmission  engine_cc  \
# 5            A4      2008.0         Audi    Petrol    Automatic     1800.0
# 18           A4      2001.0         Audi    Petrol    Automatic     1800.0
# 25           A4      2008.0         Audi    Petrol    Automatic     1800.0
# 28           A4      2010.0         Audi    Petrol    Automatic     1800.0
# 30           A4      2017.0         Audi    Petrol    Automatic     1400.0
# ...         ...         ...          ...       ...          ...        ...
# 15288   Corolla      2012.0       Toyota    Petrol    Automatic     1600.0
# 15289     Hilux      2023.0       Toyota    Diesel    Automatic     2800.0
# 15290      Vitz      2010.0       Toyota    Petrol    Automatic     1000.0
# 15291     Hilux      2023.0       Toyota    Diesel    Automatic     2800.0
# 15292  Fortuner      2021.0       Toyota    Diesel    Automatic     2800.0
#
#        kms_driven   price_pkr
# 5        100000.0   4700000.0
# ...

# %%
car_names_to_drop = ['Alpha', 'Bravo', 'Beetle', 'M38', 'Polo']

data = data[~data['car_name'].isin(car_names_to_drop)]

# %%
data.to_csv("used_car_dataset_processed(khi).csv")
